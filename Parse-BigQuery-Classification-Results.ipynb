# %%
import pandas as pd

# %%
df = pd.read_csv('csv_files/bq-results-20231219-182846-1703010757852.csv')

# %%
df
# Out:
#                             ml_understand_text_result  \
# 0   {"categories":[{"confidence":0.48011822,"name"...
# 1                                   {"categories":[]}
# 2   {"categories":[{"confidence":0.447566,"name":"...
# 3   {"categories":[{"confidence":0.13898219,"name"...
# 4   {"categories":[{"confidence":0.36051682,"name"...
# ..                                                ...
# 94  {"categories":[{"confidence":0.61469501,"name"...
# 95  {"categories":[{"confidence":0.37864521,"name"...
# 96  {"categories":[{"confidence":0.72842705,"name"...
# 97  {"categories":[{"confidence":0.60394037,"name"...
# 98  {"categories":[{"confidence":0.74569207,"name"...
#
#     ml_understand_text_status        identifier           file_name  \
# 0                         NaN  tobacco_qno71d00  VTS_01_1_512kb.mp4
# 1                         NaN  tobacco_kon79e00  VTS_01_1_512kb.mp4
# 2                         NaN  opioids_yfxh0257   yfxh0257-0002.mp4
# ...
